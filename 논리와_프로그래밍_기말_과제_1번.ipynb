# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonjunhyeok/Python-/blob/main/%EB%85%BC%EB%A6%AC%EC%99%80_%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_%EA%B8%B0%EB%A7%90_%EA%B3%BC%EC%A0%9C_1%EB%B2%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# matplotlib 실습
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,3)
y1=x**2
y2=np.sin(3*x+7)
y=y1+y2
plt.plot(x,y)
plt.show()

# %%
#Grant descent 실습 

import numpy as np
import matplotlib.pyplot as plt
#import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**2 + b**2 + np.cos(a+b)

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2.5, -2.5], iters =30, alpha = 0.045)


fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')

a = np.arange(-3, 3, 0.25)
b = np.arange(-3, 3, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [12.78366219  9.71615806  7.22669584  5.38508533  4.10573036  3.24128464
#   2.65763259  2.25764112  1.97741138  1.77629768  1.62851413  1.51750035
#   1.43241817  1.36602194  1.3133623   1.27098747  1.23644268  1.2079502
#   1.18420087  1.1642157   1.14725211  1.13273953  1.12023426  1.10938746
#   1.09992204  1.09161584  1.0842892   1.07779562  1.07201474  1.06684701
#   1.06220953]

# %%
import seaborn as sns
targetUrl_caffeine="https://raw.githubusercontent.com/jeonjunhyeok/Jeonjunhyeok/main/caffeine.csv"
Caffeine = pd.read_csv(targetUrl_caffeine)
sns.set_theme()
sns.set(rc={"figure.dpi":300}) #이미지 품질 설정
sns.set(rc={"figure.figsize":(6,3)}) ## 크기설정
## Scatter plot 산점도
sns.scatterplot(x="Volume (ml)", y ="Calories", data=Caffeine, hue="type")

# %%
sns.histplot( y= "Calories", data = Caffeine)

# %%
sns.histplot( x= "Volume (ml)", data = Caffeine)

# %%
sns.histplot( x= "Volume (ml)", data = Caffeine, kde = "True")
